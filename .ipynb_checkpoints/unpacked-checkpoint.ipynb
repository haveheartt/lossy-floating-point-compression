# %%
# import numpy as np
# import os
# import matplotlib.pyplot as plt
# import zlib

# # Generate data from three distributions
# def generate_data(size=100000):
#     uniform_data = np.random.uniform(-100, 100, size).astype(np.float32)
#     gaussian_data = np.random.normal(0, 50, size).astype(np.float32)
#     exponential_data = np.random.exponential(50, size).astype(np.float32)
#     return uniform_data, gaussian_data, exponential_data

# # Zero out LSBs of the mantissa
# def zero_lsb(data, num_bits):
#     """
#     Zero out the specified number of least significant bits (LSBs) of the mantissa.
#     """
#     # Convert float32 to uint32 to manipulate bits
#     data_int = data.view(np.uint32)
#     mask = 0xFFFFFFFF ^ ((1 << num_bits) - 1)  # Create mask to zero out LSBs
#     data_int &= mask  # Apply mask
#     return data_int.view(np.float32)  # Convert back to float32

# # Improved exponential compression
# def compress_exponential(data):
#     """
#     Improved exponential compression strategy:
#     - Use log-scaling for large values.
#     - Preserve small values in full precision.
#     """
#     compressed_data = np.zeros_like(data, dtype=np.float32)
    
#     # For small values, preserve full precision
#     small_mask = data < 100
#     compressed_data[small_mask] = data[small_mask]
    
#     # For large values, use log-scaling
#     large_mask = ~small_mask
#     if np.any(large_mask):
#         log_values = np.log1p(data[large_mask])
#         compressed_data[large_mask] = log_values
    
#     return compressed_data, small_mask

# def decompress_exponential(compressed_data, small_mask):
#     """
#     Decompress exponential data using the stored transform metadata.
#     """
#     decompressed = np.zeros_like(compressed_data, dtype=np.float32)
    
#     # Small values are directly copied
#     decompressed[small_mask] = compressed_data[small_mask]
    
#     # Large values need reverse log transform
#     large_mask = ~small_mask
#     if np.any(large_mask):
#         decompressed[large_mask] = np.expm1(compressed_data[large_mask])
    
#     return decompressed

# # Save data to binary file
# def save_to_file(data, filename, use_huffman=False):
#     """ Save to file with optional Huffman compression """
#     raw_bytes = data.tobytes()
#     if use_huffman:
#         raw_bytes = zlib.compress(raw_bytes)  # Apply Huffman compression
#     with open(filename, 'wb') as f:
#         f.write(raw_bytes)

# # Load data from binary file
# def load_from_file(filename, dtype=np.float32, use_huffman=False):
#     with open(filename, 'rb') as f:
#         raw_bytes = f.read()
#     if use_huffman:
#         raw_bytes = zlib.decompress(raw_bytes)  # Decompress Huffman data
#     return np.frombuffer(raw_bytes, dtype=dtype)

# # Calculate statistics
# def calculate_statistics(data):
#     """ Ensure calculations are done in float32 to avoid float16 overflow """
#     data = data.astype(np.float32)  # Convert back to float32 before stats
#     return {
#         'mean': np.mean(data),
#         'std': np.std(data),
#         'min': np.min(data),
#         'max': np.max(data),
#     }

# # Compute Mean Squared Error (MSE)
# def calculate_mse(original, compressed):
#     """ Calculate MSE between original and compressed data """
#     original = original.astype(np.float32)  # Ensure correct type
#     compressed = compressed.astype(np.float32)
#     return np.mean((original - compressed) ** 2)

# # Plot distributions
# def plot_distributions(original, compressed, title):
#     plt.figure(figsize=(12, 6))
#     plt.hist(original, bins=100, alpha=0.5, label='Original', density=True)
#     plt.hist(compressed, bins=100, alpha=0.5, label='Compressed', density=True)
#     plt.title(title)
#     plt.legend()
#     plt.show()  # Display the plot inline

# # Plot scatter plot of original vs compressed values
# def plot_scatter(original, compressed, title):
#     plt.figure(figsize=(8, 8))
#     plt.scatter(original, compressed, alpha=0.5, s=1)
#     plt.plot([original.min(), original.max()], [original.min(), original.max()], 'r--')
#     plt.title(f"Scatter Plot: {title}")
#     plt.xlabel("Original")
#     plt.ylabel("Compressed")
#     plt.show()  # Display the plot inline

# # Plot CDFs of original and compressed data
# def plot_cdf(original, compressed, title):
#     plt.figure(figsize=(12, 6))
#     plt.hist(original, bins=1000, cumulative=True, histtype='step', density=True, label='Original')
#     plt.hist(compressed, bins=1000, cumulative=True, histtype='step', density=True, label='Compressed')
#     plt.title(f"CDF: {title}")
#     plt.legend()
#     plt.show()  # Display the plot inline

# # Main function
# def main():
#     size = 100000
#     print("Generating data from three distributions...")
#     uniform_data, gaussian_data, exponential_data = generate_data(size)

#     # Save original data
#     print("Saving original data...")
#     save_to_file(uniform_data, 'uniform_original.bin')
#     save_to_file(gaussian_data, 'gaussian_original.bin')
#     save_to_file(exponential_data, 'exponential_original.bin')

#     # Compress data by zeroing out 12 LSBs
#     print("Compressing data by zeroing out 12 LSBs...")
#     uniform_compressed = zero_lsb(uniform_data, 12)
#     gaussian_compressed = zero_lsb(gaussian_data, 12)
    
#     # Compress exponential data with specialized method
#     exponential_compressed_storage, small_mask = compress_exponential(exponential_data)
#     # Apply bit reduction to the compressed representation for additional savings
#     exponential_compressed_storage = zero_lsb(exponential_compressed_storage, 12)

#     # Save compressed data
#     print("Saving compressed data...")
#     save_to_file(uniform_compressed, 'uniform_compressed.bin', use_huffman=True)
#     save_to_file(gaussian_compressed, 'gaussian_compressed.bin', use_huffman=True)
#     save_to_file(exponential_compressed_storage, 'exponential_compressed.bin', use_huffman=True)
#     save_to_file(small_mask.astype(np.uint8), 'exponential_mask.bin')

#     # Decompress exponential data for analysis
#     exponential_decompressed = decompress_exponential(exponential_compressed_storage, small_mask)

#     # Measure file sizes
#     original_files = ['uniform_original.bin', 'gaussian_original.bin', 'exponential_original.bin']
#     compressed_files = ['uniform_compressed.bin', 'gaussian_compressed.bin', 'exponential_compressed.bin']
    
#     print("\nFile Size Comparison:")
#     for orig, comp in zip(original_files, compressed_files):
#         orig_size = os.path.getsize(orig)
#         comp_size = os.path.getsize(comp)
#         savings = orig_size - comp_size
#         compression_ratio = orig_size / comp_size if comp_size > 0 else float('inf')
#         print(f"{orig}: Original Size = {orig_size} bytes, Compressed Size = {comp_size} bytes")
#         print(f"  Savings = {savings} bytes, Compression Ratio = {compression_ratio:.2f}x")

#     # Compare statistical parameters
#     print("\nStatistical Comparison:")
#     for name, orig, comp in zip(
#         ["Uniform", "Gaussian", "Exponential"],
#         [uniform_data, gaussian_data, exponential_data],
#         [uniform_compressed, gaussian_compressed, exponential_decompressed]  # Using decompressed data here
#     ):
#         print(f"\n{name} Data Statistics:")
#         print("Original:", calculate_statistics(orig))
#         print("Compressed:", calculate_statistics(comp))

#     # Calculate MSE between original and compressed data
#     print("\nMean Squared Error (MSE):")
#     print("Uniform:", calculate_mse(uniform_data, uniform_compressed))
#     print("Gaussian:", calculate_mse(gaussian_data, gaussian_compressed))
#     print("Exponential:", calculate_mse(exponential_data, exponential_decompressed))  # Using decompressed data here

#     # Plot distributions, scatter plots, and CDFs
#     print("\nGenerating plots...")
#     plot_distributions(uniform_data, uniform_compressed, 'Uniform Distribution')
#     plot_distributions(gaussian_data, gaussian_compressed, 'Gaussian Distribution')
#     plot_distributions(exponential_data, exponential_decompressed, 'Exponential Distribution')  # Using decompressed data here

#     plot_scatter(uniform_data, uniform_compressed, 'Uniform')
#     plot_scatter(gaussian_data, gaussian_compressed, 'Gaussian')
#     plot_scatter(exponential_data, exponential_decompressed, 'Exponential')  # Using decompressed data here

#     plot_cdf(uniform_data, uniform_compressed, 'Uniform')
#     plot_cdf(gaussian_data, gaussian_compressed, 'Gaussian')
#     plot_cdf(exponential_data, exponential_decompressed, 'Exponential')  # Using decompressed data here

# if __name__ == "__main__":
#     main()

# %%
import numpy as np
import struct
import os
import matplotlib.pyplot as plt

# Generate samples from uniform, Gaussian, and exponential distributions
def generate_distributions(n_samples=100000):
    uniform = np.random.uniform(-100, 100, n_samples)
    gaussian = np.random.normal(0, 10, n_samples)
    exponential = np.random.exponential(10, n_samples)
    
    return {
        'uniform': uniform,
        'gaussian': gaussian,
        'exponential': exponential
    }

class FloatCompressor:

    # Total number of mantissa bits in IEEE 754 single precision 
    NMANTISSA = 23

    def __init__(self, mantissa_bits):
        self.mantissa_bits = mantissa_bits
        self.mantissa_bitmask = 0

        # Adjust the received bit number to some reasonable value:
        if self.mantissa_bits < 5:
            self.mantissa_bits = 5
        if self.mantissa_bits > self.NMANTISSA:
            self.mantissa_bits = self.NMANTISSA

        # Fill up the lower N bits
        for i in range(self.NMANTISSA - self.mantissa_bits):
            self.mantissa_bitmask |= (0x1 << i)
        # And now negate it to get the correct mask:
        self.mantissa_bitmask = ~self.mantissa_bitmask

        # Set the Magic numbers
        if self.mantissa_bits == self.NMANTISSA:
            self.rounding = 0
        else:
            self.rounding = 0x1 << (32 - (1 + 8 + self.mantissa_bits) - 1)

        self.vmax = 0x7f7 << 20
        self.vmax |= 0x000fffff ^ self.rounding

    def reduce_float_precision(self, value):
        
        # Check if any compression is to be made
        if self.mantissa_bits == self.NMANTISSA:
            return value

        # Check for NaN, etc
        if not np.isfinite(value):
            return value

        # Convert float to its 32-bit integer representation
        ivalue = np.float32(value).view(np.int32)

        # Safety-check if value (omitting the sign-bit) is lower than vmax (avoid overflow)
        if (ivalue & 0x7fffffff) < self.vmax:
            ivalue += self.rounding

        # Do the compression
        ivalue &= self.mantissa_bitmask

        # Convert the integer back to a float
        fvalue = ivalue.view(np.float32)
        return fvalue.item()  # Convert numpy float32 to Python float

# Function to pack a 32-bit float into a custom 20-bit format
def pack_float(value, mantissa_bits_to_keep):
    ivalue = np.float32(value).view(np.int32)
    sign = (ivalue >> 31) & 0x1 # Extract sign bit
    exponent = (ivalue >> 23) & 0xFF # Extract exponent bits
    mantissa = (ivalue & 0x7FFFFF) >> (23 - mantissa_bits_to_keep)  # Keep only significant mantissa bits
    packed = (sign << 19) | (exponent << 11) | mantissa
    return packed

# Function to unpack a custom 20-bit format into a 32-bit float
def unpack_float(packed):
    sign = (packed >> 19) & 0x1 # Extract sign bit
    exponent = (packed >> 11) & 0xFF # Extract exponent bits
    mantissa = (packed & 0x7FF) << (23 - 11)  # Restore mantissa to 23 bits
    ivalue = (sign << 31) | (exponent << 23) | mantissa
    return np.int32(ivalue).view(np.float32)

def save_to_binary(data, filename):
    data.astype('float32').tofile(filename)
    
def get_file_size(filename):
    return os.path.getsize(filename)

def compare_statistics(original, compressed, name):
    print(f"\nStatistics for {name}:")
    print(f"Original Mean: {np.mean(original)}, Compressed Mean: {np.mean(compressed)}")
    print(f"Original Variance: {np.var(original)}, Compressed Variance: {np.var(compressed)}")
    print(f"Original Std Dev: {np.std(original)}, Compressed Std Dev: {np.std(compressed)}")

def compute_mse(original, compressed):
    return np.mean((original - compressed) ** 2)

def plot_distributions(original, compressed, name):
    plt.figure(figsize=(12, 6))
    plt.hist(original, bins=100, alpha=0.5, label='Original')
    plt.hist(compressed, bins=100, alpha=0.5, label='Compressed')
    plt.title(f'{name} Distribution')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()

# Generate a relevantly large number of floating-point numbers from three distributions (e.g. uniform, Gaussian, and exponential).
data = generate_distributions()

#  Lossy compression function to zero out between 8 and 16 least significant bits of the mantissa.
compressor = FloatCompressor(mantissa_bits=12)  # Adjust mantissa_bits as needed
compressed_data = {
    'uniform': np.array([compressor.reduce_float_precision(x) for x in data['uniform']]),
    'gaussian': np.array([compressor.reduce_float_precision(x) for x in data['gaussian']]),
    'exponential': np.array([compressor.reduce_float_precision(x) for x in data['exponential']])
}


#  Save both full-precision and compressed data to binary files.
save_to_binary(data['uniform'], 'uniform_original.bin')
save_to_binary(data['gaussian'], 'gaussian_original.bin')
save_to_binary(data['exponential'], 'exponential_original.bin')

save_to_binary(compressed_data['uniform'], 'uniform_compressed.bin')
save_to_binary(compressed_data['gaussian'], 'gaussian_compressed.bin')
save_to_binary(compressed_data['exponential'], 'exponential_compressed.bin')

#  Measure and compare on-disk file sizes to analyze storage savings achieved through compression.
print(f"Uniform Original Size: {get_file_size('uniform_original.bin')} bytes")
print(f"Uniform Compressed Size: {get_file_size('uniform_compressed.bin')} bytes")
print(f"Gaussian Original Size: {get_file_size('gaussian_original.bin')} bytes")
print(f"Gaussian Compressed Size: {get_file_size('gaussian_compressed.bin')} bytes")
print(f"Exponential Original Size: {get_file_size('exponential_original.bin')} bytes")
print(f"Exponential Compressed Size: {get_file_size('exponential_compressed.bin')} bytes")

#  Compare statistical parameters of the distributions before and after compression.
compare_statistics(data['uniform'], compressed_data['uniform'], "Uniform")
compare_statistics(data['gaussian'], compressed_data['gaussian'], "Gaussian")
compare_statistics(data['exponential'], compressed_data['exponential'], "Exponential")

#  Compute Mean Squared Error between original and compressed data.
print(f"\nMSE for Uniform: {compute_mse(data['uniform'], compressed_data['uniform'])}")
print(f"MSE for Gaussian: {compute_mse(data['gaussian'], compressed_data['gaussian'])}")
print(f"MSE for Exponential: {compute_mse(data['exponential'], compressed_data['exponential'])}")

# Plot original and compressed data to observe distribution changes.
plot_distributions(data['uniform'], compressed_data['uniform'], "Uniform")
plot_distributions(data['gaussian'], compressed_data['gaussian'], "Gaussian")
plot_distributions(data['exponential'], compressed_data['exponential'], "Exponential")
# Out:
# Uniform Original Size: 400000 bytes
# Uniform Compressed Size: 400000 bytes
# Gaussian Original Size: 400000 bytes
# Gaussian Compressed Size: 400000 bytes
# Exponential Original Size: 400000 bytes
# Exponential Compressed Size: 400000 bytes
#
# Statistics for Uniform:
# Original Mean: -0.15747534897582188, Compressed Mean: -0.15747629674233496
# Original Variance: 3342.6187816219444, Compressed Variance: 3342.6192145009936
# Original Std Dev: 57.81538533662077, Compressed Std Dev: 57.815389080252615
#
# Statistics for Gaussian:
# Original Mean: -0.09376856928139281, Compressed Mean: -0.09376858073987067
# Original Variance: 99.39522988545919, Compressed Variance: 99.39523493832365
# Original Std Dev: 9.969715637141272, Compressed Std Dev: 9.96971589055193
#
# Statistics for Exponential:
# Original Mean: 10.002495244129912, Compressed Mean: 10.002495679186334
# Original Variance: 100.73684634755759, Compressed Variance: 100.7368579532299
# ...

# %%
import numpy as np
import struct
import os
import matplotlib.pyplot as plt

# Generate samples from uniform, Gaussian, and exponential distributions
def generate_distributions(n_samples=100000):
    uniform = np.random.uniform(-100, 100, n_samples)
    gaussian = np.random.normal(0, 10, n_samples)
    exponential = np.random.exponential(10, n_samples)
    
    return {
        'uniform': uniform,
        'gaussian': gaussian,
        'exponential': exponential
    }

class FloatCompressor:
    # Total number of mantissa bits in IEEE 754 single precision 
    NMANTISSA = 23

    def __init__(self, mantissa_bits):
        self.mantissa_bits = mantissa_bits
        self.mantissa_bitmask = 0

        # Adjust the received bit number to some reasonable value:
        if self.mantissa_bits < 5:
            self.mantissa_bits = 5
        if self.mantissa_bits > self.NMANTISSA:
            self.mantissa_bits = self.NMANTISSA

        # Fill up the lower N bits
        for i in range(self.NMANTISSA - self.mantissa_bits):
            self.mantissa_bitmask |= (0x1 << i)
        # And now negate it to get the correct mask:
        self.mantissa_bitmask = ~self.mantissa_bitmask

        # Set the Magic numbers
        if self.mantissa_bits == self.NMANTISSA:
            self.rounding = 0
        else:
            self.rounding = 0x1 << (32 - (1 + 8 + self.mantissa_bits) - 1)

        self.vmax = 0x7f7 << 20
        self.vmax |= 0x000fffff ^ self.rounding

    def reduce_float_precision(self, value):
        # Check if any compression is to be made
        if self.mantissa_bits == self.NMANTISSA:
            return value

        # Check for NaN, etc
        if not np.isfinite(value):
            return value

        # Convert float to its 32-bit integer representation
        ivalue = np.float32(value).view(np.int32)

        # Safety-check if value (omitting the sign-bit) is lower than vmax (avoid overflow)
        if (ivalue & 0x7fffffff) < self.vmax:
            ivalue += self.rounding

        # Do the compression
        ivalue &= self.mantissa_bitmask

        # Convert the integer back to a float
        fvalue = ivalue.view(np.float32)
        return fvalue.item()  # Convert numpy float32 to Python float

# Function to pack a 32-bit float into a custom 20-bit format
def pack_float(value, mantissa_bits_to_keep):
    ivalue = np.float32(value).view(np.int32)
    sign = (ivalue >> 31) & 0x1  # Extract sign bit
    exponent = (ivalue >> 23) & 0xFF  # Extract exponent bits
    mantissa = (ivalue & 0x7FFFFF) >> (23 - mantissa_bits_to_keep)  # Keep only significant mantissa bits
    packed = (sign << 19) | (exponent << 11) | mantissa  # Pack into 20 bits
    return packed

# Function to unpack a custom 20-bit format into a 32-bit float
def unpack_float(packed):
    sign = (packed >> 19) & 0x1  # Extract sign bit
    exponent = (packed >> 11) & 0xFF  # Extract exponent bits
    mantissa = (packed & 0x7FF) << (23 - 11)  # Restore mantissa to 23 bits
    ivalue = (sign << 31) | (exponent << 23) | mantissa  # Reconstruct 32-bit integer
    return np.uint32(ivalue).view(np.float32)  # Treat as uint32 to avoid overflow

# Function to pack multiple 20-bit values into 32-bit integers
def pack_data(packed_values):
    packed_data = []
    buffer = np.uint32(0)  # Use uint32 to avoid overflow
    bits_in_buffer = 0

    for value in packed_values:
        buffer |= np.uint32(value & 0xFFFFF) << np.uint32(bits_in_buffer)  # Mask value to 20 bits and add to buffer
        bits_in_buffer += 20

        if bits_in_buffer >= 32:
            packed_data.append(buffer & 0xFFFFFFFF)  # Store lower 32 bits
            buffer >>= np.uint32(32)  # Shift buffer to keep remaining bits
            bits_in_buffer -= 32

    if bits_in_buffer > 0:
        packed_data.append(buffer & 0xFFFFFFFF)  # Store remaining bits

    return packed_data

# Function to unpack multiple 20-bit values from 32-bit integers
def unpack_data(packed_data):
    unpacked_values = []
    buffer = np.uint32(0)  # Use uint32 to avoid overflow
    bits_in_buffer = 0

    for packed in packed_data:
        buffer |= np.uint32(packed & 0xFFFFFFFF) << np.uint32(bits_in_buffer)  # Add packed data to buffer
        bits_in_buffer += 32

        while bits_in_buffer >= 20:
            unpacked_values.append(buffer & 0xFFFFF)  # Extract 20 bits
            buffer >>= np.uint32(20)
            bits_in_buffer -= 20

    return unpacked_values

# Save packed data to a binary file
def save_packed_data(packed_data, filename):
    with open(filename, 'wb') as f:
        for packed in packed_data:
            f.write(struct.pack('I', packed))  # Store as 32-bit unsigned int (4 bytes)

# Load packed data from a binary file
def load_packed_data(filename):
    packed_data = []
    with open(filename, 'rb') as f:
        while True:
            packed = f.read(4)  # Read 4 bytes (32 bits)
            if not packed:
                break
            packed_data.append(struct.unpack('I', packed)[0])  # Unpack as 32-bit unsigned int
    return packed_data

def save_to_binary(data, filename):
    data.astype('float32').tofile(filename)

# Generate a relevantly large number of floating-point numbers from three distributions (e.g. uniform, Gaussian, and exponential).
data = generate_distributions()

# Lossy compression function to zero out between 8 and 16 least significant bits of the mantissa.
compressor = FloatCompressor(mantissa_bits=12)  # Adjust mantissa_bits as needed
compressed_data = {
    'uniform': np.array([compressor.reduce_float_precision(x) for x in data['uniform']]),
    'gaussian': np.array([compressor.reduce_float_precision(x) for x in data['gaussian']]),
    'exponential': np.array([compressor.reduce_float_precision(x) for x in data['exponential']])
}

# Pack the compressed data into a custom 20-bit format
packed_values = {
    'uniform': [pack_float(x, 11) for x in compressed_data['uniform']],
    'gaussian': [pack_float(x, 11) for x in compressed_data['gaussian']],
    'exponential': [pack_float(x, 11) for x in compressed_data['exponential']]
}

# Pack multiple 20-bit values into 32-bit integers
packed_data = {
    'uniform': pack_data(packed_values['uniform']),
    'gaussian': pack_data(packed_values['gaussian']),
    'exponential': pack_data(packed_values['exponential'])
}

save_to_binary(data['uniform'], 'uniform_original.bin')
save_to_binary(data['gaussian'], 'gaussian_original.bin')
save_to_binary(data['exponential'], 'exponential_original.bin')

# Save packed data to binary files
save_packed_data(packed_data['uniform'], 'uniform_compressed_packed.bin')
save_packed_data(packed_data['gaussian'], 'gaussian_compressed_packed.bin')
save_packed_data(packed_data['exponential'], 'exponential_compressed_packed.bin')

# Measure and compare on-disk file sizes to analyze storage savings achieved through compression.
print(f"Uniform Original Size: {os.path.getsize('uniform_original.bin')} bytes")
print(f"Uniform Compressed Size (Packed): {os.path.getsize('uniform_compressed_packed.bin')} bytes")
print(f"Gaussian Original Size: {os.path.getsize('gaussian_original.bin')} bytes")
print(f"Gaussian Compressed Size (Packed): {os.path.getsize('gaussian_compressed_packed.bin')} bytes")
print(f"Exponential Original Size: {os.path.getsize('exponential_original.bin')} bytes")
print(f"Exponential Compressed Size (Packed): {os.path.getsize('exponential_compressed_packed.bin')} bytes")

# Load packed data and unpack it
unpacked_values = {
    'uniform': unpack_data(load_packed_data('uniform_compressed_packed.bin')),
    'gaussian': unpack_data(load_packed_data('gaussian_compressed_packed.bin')),
    'exponential': unpack_data(load_packed_data('exponential_compressed_packed.bin'))
}

# Unpack the 20-bit values into floats
unpacked_data = {
    'uniform': np.array([unpack_float(x) for x in unpacked_values['uniform']]),
    'gaussian': np.array([unpack_float(x) for x in unpacked_values['gaussian']]),
    'exponential': np.array([unpack_float(x) for x in unpacked_values['exponential']])
}

# Compare statistical parameters of the distributions before and after compression.
compare_statistics(data['uniform'], unpacked_data['uniform'], "Uniform")
compare_statistics(data['gaussian'], unpacked_data['gaussian'], "Gaussian")
compare_statistics(data['exponential'], unpacked_data['exponential'], "Exponential")

# Compute Mean Squared Error between original and compressed data.
print(f"\nMSE for Uniform: {compute_mse(data['uniform'], unpacked_data['uniform'])}")
print(f"MSE for Gaussian: {compute_mse(data['gaussian'], unpacked_data['gaussian'])}")
print(f"MSE for Exponential: {compute_mse(data['exponential'], unpacked_data['exponential'])}")

# Plot original and compressed data to observe distribution changes.
plot_distributions(data['uniform'], unpacked_data['uniform'], "Uniform")
plot_distributions(data['gaussian'], unpacked_data['gaussian'], "Gaussian")
plot_distributions(data['exponential'], unpacked_data['exponential'], "Exponential")
# Out:
# Uniform Original Size: 400000 bytes
# Uniform Compressed Size (Packed): 250000 bytes
# Gaussian Original Size: 400000 bytes
# Gaussian Compressed Size (Packed): 250000 bytes
# Exponential Original Size: 400000 bytes
# Exponential Compressed Size (Packed): 250000 bytes
#
# Statistics for Uniform:
# Original Mean: 0.03639397107880399, Compressed Mean: 0.014072083868086338
# Original Variance: 3343.4714857545673, Compressed Variance: 415.3149719238281
# Original Std Dev: 57.82275923677948, Compressed Std Dev: 20.3792781829834
#
# Statistics for Gaussian:
# Original Mean: 0.00961228676210779, Compressed Mean: 0.00462443707510829
# Original Variance: 99.80177904019774, Compressed Variance: 12.472023963928223
# Original Std Dev: 9.99008403569248, Compressed Std Dev: 3.5315752029418945
#
# Statistics for Exponential:
# Original Mean: 9.942497339075226, Compressed Mean: 1.2449402809143066
# Original Variance: 99.01171495088586, Compressed Variance: 22.893321990966797
# ...
